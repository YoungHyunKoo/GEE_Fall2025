# %% [markdown]
# <a href="https://colab.research.google.com/github/YoungHyunKoo/GEE_Fall2025/blob/main/Assignment_Fall2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **[GEO 6053] Remote Sensing - Fall 2025**
# # **Assignments**
#
# > **Due by Nov 12, 2025 (Wed) 06:00 pm**
#
# ### Submission instructions
# 1. Please copy this notebook in your Google Drive. (`File` > `Save a copy in Drive`)
# 2. Rename the notebook into ***Fall2025_GEE_Assignments_LASTNAME***. Put your lastname.
# 3. Once you complete the tasks, please press the `Share` button on the top right corner. Change the "General Access" to ***Anyone with this link*** and ***Viewer***.
# 4. Press the `Copy link` button. Paste this link and submit to Canvas.

# %% [markdown]
# ## **1. Task 1: Monitoring August Complex Fires (60 pts)**
#
# From August 2020 to November 2020, there was a large wildfire in Glenn County, CA (August Complex Fires).
#
# - Find a Landsat 8 image collection available for this location: latitude 39.71, longitude -122.69. **[5 pts]**
# - Find a Landsat 8 imagery during the wildfire (i.e. August 2020 to November 2020) and visulize it on the map. Can you identify any wildfire in that imagery? **[10 pts]**
# - Find Landsat 8 images before and after the wildfire, **but in the same month of two different years** (e.g. July 2020 and July 2021). Visualize them on the map as true color images. **[15 pts]**
# - For these two images, please calculate Normalized Burn Ratio (NBR) and visualize them on the map with appropriate palette option: [NBR](https://www.usgs.gov/landsat-missions/landsat-normalized-burn-ratio) **[15 pts]**
# - Calculate the difference in NBR. Can you identify burned area from the difference in NBR index? **[15 pts]**

# %%
# Please use this Landsat 8 image collection
ee.ImageCollection("LANDSAT/LC08/C02/T1_TOA")

# %% [markdown]
# ## **2. Task 2: Elevation & Temperature (40 pts)**
#
# - What is the state FIPS code of Coloardo (CO)?
# - Calculate the mean elevation for all counties in Colorado using SRTM elevation data. **[15 pts]**
#
# [SRTM Digital Elevation Data](https://developers.google.com/earth-engine/datasets/catalog/CGIAR_SRTM90_V4)
# - Calculate the mean surface temperature for all CO counties in January 2018 using MODIS surface temperature data. **[15 pts]**
#
# [MOD11A2.061 Terra Land Surface Temperature and Emissivity 8-Day Global 1km](https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MOD11A2)
#
# - Draw a scatter plot between the mean elevation and temperature for all CO counties. Do you find any significant trend between elevation and temperature? Why? **[10 pts]**

# %%
# Please use this SRTM elevation image
elev = ee.Image("CGIAR/SRTM90_V4")

# Please use this MODIS surface temperature image collection;
# Filter date to January 2018 and reduce the image collection to extract the mean surface temperature.
temp = ee.ImageCollection("MODIS/061/MOD11A2")

# %% [markdown]
# ## **3. Task 3:  (Bonus 10 pts)**
#
# - You will investigate the time series of NDVI around the Glenn County to see how the wildfire event changed vegetation cover in this area. Please extract the time series of NDVI from 2010 to 2024 at the region of intereset in Task 1 (latitude 39.71, longitude -122.69) using the MODIS NDVI image collection below. Please discuss how NDVI changed during the wildfire event and thereafter. **[10 pts]**
#
# [MODIS Terra Vegetation Indices 16-Day Global 500m](https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MOD13A1)

# %%
# Please use this MODIS NDVI image collection
ee.ImageCollection("MODIS/061/MOD13A1")
